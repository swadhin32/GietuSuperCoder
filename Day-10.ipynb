# %%
class Node:
    def __init__(self, data, left=None, right=None):
        self.data = data
        self.left = left
        self.right = right
 
 
def inorder(root):
    if root is None:
        return
 
    inorder(root.left)
    print(root.data, end=' ')
    inorder(root.right)
 
 
def getMinimumKey(curr):
    while curr.left:
        curr = curr.left
    return curr
 
def insert(root, key):
 
    if root is None:
        return Node(key)
 
    if key < root.data:
        root.left = insert(root.left, key)
 
    else:
        root.right = insert(root.right, key)
 
    return root
 
def deleteNode(root, key):
 
    parent = None
 
    curr = root
 
    while curr and curr.data != key:
 
        parent = curr
 
        if key < curr.data:
            curr = curr.left
        else:
            curr = curr.right
 
    if curr is None:
        return root
 
    if curr.left is None and curr.right is None:
 
        if curr != root:
            if parent.left == curr:
                parent.left = None
            else:
                parent.right = None
 
        else:
            root = None
 
    elif curr.left and curr.right:
 
        successor = getMinimumKey(curr.right)
        val = successor.data
        deleteNode(root, successor.data)
        curr.data = val
 
    else:
 
        if curr.left:
            child = curr.left
        else:
            child = curr.right
 
        if curr != root:
            if curr == parent.left:
                parent.left = child
            else:
                parent.right = child
 
        else:
            root = child
 
    return root
  
if __name__ == '__main__':
 
    keys = [15, 10, 20, 8, 12, 16]
 
    root = None
    for key in keys:
        root = insert(root, key)
 
    root = deleteNode(root, 16)
    inorder(root)
# Out:
# 8 10 12 15 20

# %%
class Queue:
    def __init__(self, max_size):
        self.__max_size=max_size
        self.__elements = [None]*max_size
        self.__front = 0
        self.__rear = -1
        
    def is_empty(self):
        if self.__front>self.__rear:
            return True
        return False
            
    def is_full(self):
        if self.__rear==self.__max_size-1:
            return True
        return False
    def enqueue(self,data):
        if(self.is_full()):
            print("Queue is full")
        else:
            self.__rear+=1
            self.__elements[self.__rear]=data
    def dequeue(self):
        if(self.is_empty()):
            print("Queue is empty!!!")
        else:
            data = self.__elements[self.__front]
            self.__front+=1
            return data
    def display(self):
        for i in range(self.__front, self.__rear+1):
             print(self.__elements[i])
    def get_max_size(self):
        return self.__max_size
    def oddeven(self,oddq,evenq):
        for i in range(self.__front, self.__rear+1):
            if self.__elements[i]%2==1:
                oddq.enqueue(self.__elements[i])
            else:
                evenq.enqueue(self.__elements[i])

queue1 = Queue(5)
oddq = Queue(5)
evenq = Queue(5)
queue1.enqueue(101)
queue1.enqueue(200)
queue1.enqueue(300)
queue1.enqueue(403)
queue1.enqueue(500)
queue1.oddeven(oddq,evenq)
queue1.display()
print("odd q is ")
oddq.display()
print("Even q is ")
evenq.display()
# Out:
# 101
# 200
# 300
# 403
# 500
# odd q is
# 101
# 403
# Even q is
# 200
# 300
# 500

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class SLinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print (printval.dataval)
            printval = printval.nextval
    def AtBegining(self,newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode
    def AtEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        laste = self.headval
        while(laste.nextval):
            laste = laste.nextval
        laste.nextval = NewNode
    def merge(self,list1,list2,n):
        count=0
        printval = self.headval
        list1temp = list1.headval
        list2temp = list2.headval
        while list1temp is not None:
            
            self.AtEnd(list1temp.dataval)
            count = count+1
            if count==n:
                while list2temp is not None:
                    self.AtEnd(list2temp.dataval)
                    list2temp=list2temp.nextval
                count = count+1
            list1temp = list1temp.nextval
            

list1 = SLinkedList()
list1.headval = Node(1)
list1.AtEnd(2)
list1.AtEnd(4)
list1.AtEnd(3)
list1.AtEnd(5)
list2 = SLinkedList()
list2.headval = Node(9)
list2.AtEnd(8)
list2.AtEnd(11)
list3 = SLinkedList()
list3.merge(list1,list2,2)
list3.listprint()
# Out:
# 1
# 2
# 9
# 8
# 11
# 4
# 3
# 5

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class SLinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print (printval.dataval)
            printval = printval.nextval
    def AtBegining(self,newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode
    def AtEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return
        laste = self.headval
        while(laste.nextval):
            laste = laste.nextval
        laste.nextval = NewNode
    def replace_maximum(self,n):
        printval = self.headval
        maxm = 0
        maxnode = None
        while printval is not None:
            if printval.dataval>maxm:
                maxnode = printval
            printval = printval.nextval
        maxnode.dataval=n
            

list1 = SLinkedList()
list1.headval = Node(1)
list1.AtEnd(2)
list1.AtEnd(4)
list1.AtEnd(3)
list1.AtEnd(5)
list1.replace_maximum(100)
list1.listprint()
# Out:
# 1
# 2
# 4
# 3
# 100

# %% [markdown]
# !(https://drive.google.com/file/d/12EoJ9YM2zE46vXP5TJ88v8K9BA_k35Ub/preview)

# %%
class Stack:
    def __init__(self, max_size):
        self.__max_size = max_size
        self.__elements = [None]*self.__max_size
        self.__top = -1
        
    def is_full(self):
        if(self.__top==self.__max_size-1):
            return True
        return False
    
    def is_empty(self):
        if(self.__top==-1):
            return True
        return False
    def push(self, data):
        if(self.is_full()):
            print("Stack is full can't insert")
        else:
            self.__top=self.__top+1
            self.__elements[self.__top]=data
    def pop(self):
        if(self.is_empty()):
            print("Stack is empty")
        else:
            self.__top=self.__top-1
    def display(self):
        if(self.is_empty()):
            print("Stack is empty")
        else:
            index = self.__top
            while(index>=0):
                print(self.__elements[index])
                index-=1
    def get_max_size(self):
        return self.__max_size
    
    
    
    
    
    
    
class Queue:
    def __init__(self, max_size):
        self.__max_size=max_size
        self.__elements = [None]*max_size
        self.__front = 0
        self.__rear = -1
        
    def is_empty(self):
        if self.__front>self.__rear:
            return True
        return False
            
    def is_full(self):
        if self.__rear==self.__max_size-1:
            return True
        return False
    def enqueue(self,data):
        if(self.is_full()):
            print("Queue is full")
        else:
            self.__rear+=1
            self.__elements[self.__rear]=data
    def dequeue(self):
        if(self.is_empty()):
            print("Queue is empty!!!")
        else:
            data = self.__elements[self.__front]
            self.__front+=1
            return data
    def display(self):
        for i in range(self.__front, self.__rear+1):
             print(self.__elements[i],end=" ")
    def get_max_size(self):
        return self.__max_size
    def triangle(self,s1):
        for i in range(self.__front-1, self.__rear+1):
            if self.__elements[i-1]*(self.__elements[i-1]+1)//2==self.__elements[i]:
                s1.push(self.__elements[i])
                

queue1 = Queue(10)
queue1.enqueue(7)
queue1.enqueue(28)
queue1.enqueue(8)
queue1.enqueue(35)
queue1.enqueue(3)
queue1.enqueue(6)
queue1.enqueue(5)
queue1.enqueue(15)
queue1.enqueue(2)
queue1.enqueue(5)

print("In queue=",end = "  ")
queue1.display()
s1 = Stack(10)
queue1.triangle(s1)
print("\nExpected Output=")
s1.display()
# Out:
# In queue=  7 28 8 35 3 6 5 15 2 5
# Expected Output=
# 15
# 6
# 28
